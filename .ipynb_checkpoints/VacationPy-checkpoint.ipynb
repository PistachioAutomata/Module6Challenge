# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import warnings
warnings.filterwarnings("ignore")


# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat       Lng  Max Temp  \
# 0        0                       kenora  49.8167  -94.4337     20.54
# 1        1  edinburgh of the seven seas -37.0676  -12.3116     12.93
# 2        2                    papatowai -46.5619  169.4708      9.50
# 3        3                      ushuaia -54.8000  -68.3000      3.81
# 4        4            port-aux-francais -49.3500   70.2167      3.16
#
#    Humidity  Cloudiness  Wind Speed Country                      Date
# 0        83         100        3.60      CA  Mon Jul 22 18:36:52 2024
# 1        78         100       10.82      SH  Mon Jul 22 18:36:54 2024
# 2        74          94        3.99      NZ  Mon Jul 22 18:36:55 2024
# 3        75          40       10.80      AR  Mon Jul 22 18:36:57 2024
# 4        69          55        3.85      TF  Mon Jul 22 18:36:58 2024

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 650,
    frame_height = 450,
    size = "Humidity",
    scale = 0.8,
    color = "City",
    alpha = 0.5
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_cities_df = city_data_df.loc[(city_data_df["Max Temp"] >= 18) & (city_data_df["Max Temp"] <= 28) & (city_data_df["Humidity"] <= 70)]

# Drop any rows with null values
ideal_cities_df = ideal_cities_df.dropna(how = 'any',inplace = False,ignore_index = True)

# Display sample data
ideal_cities_df
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 0          5         albany  42.6001  -73.9662     23.57        59
# 1          7  port mathurin -19.6833   63.4167     22.84        66
# 2         28           hami  42.8000   93.4500     27.82        25
# 3         43      adamstown -25.0660 -130.1015     18.80        70
# 4         44         avarua -21.2078 -159.7750     25.03        61
# ..       ...            ...      ...       ...       ...       ...
# 100      557     jalal-abad  40.9333   73.0000     24.80        30
# 101      559  casas grandes  30.3667 -107.9500     25.29        48
# 102      564       agacoren  38.8748   33.9167     20.55        57
# 103      565     baker city  44.7749 -117.8344     26.47        60
# 104      570        birjand  32.8663   59.2211     22.26        21
#
#      Cloudiness  Wind Speed Country                      Date
# 0           100        1.37      US  Mon Jul 22 18:34:32 2024
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_cities_df[['City','Country','Lat','Lng','Humidity']]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"]=''

# Display sample data
hotel_df
# Out:
#               City Country      Lat       Lng  Humidity Hotel Name
# 0           albany      US  42.6001  -73.9662        59
# 1    port mathurin      MU -19.6833   63.4167        66
# 2             hami      CN  42.8000   93.4500        25
# 3        adamstown      PN -25.0660 -130.1015        70
# 4           avarua      CK -21.2078 -159.7750        61
# ..             ...     ...      ...       ...       ...        ...
# 100     jalal-abad      KG  40.9333   73.0000        30
# 101  casas grandes      MX  30.3667 -107.9500        48
# 102       agacoren      TR  38.8748   33.9167        57
# 103     baker city      US  44.7749 -117.8344        60
# 104        birjand      IR  32.8663   59.2211        21
#
# [105 rows x 6 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
limit = 10

params = {
    "limit":limit,
    "apiKey":geoapify_key,
    "categories":'accommodation'
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    search_lat = hotel_df.loc[index,'Lat']
    search_lng = hotel_df.loc[index,'Lng']

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{search_lng},{search_lat},{radius}"
    params["bias"] = f"proximity:{search_lng},{search_lat}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
        
    except:
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# albany - nearest hotel: No hotel found
# port mathurin - nearest hotel: Résidence Véronia
# hami - nearest hotel: Хами
# adamstown - nearest hotel: No hotel found
# avarua - nearest hotel: Central Motel
# kizhinga - nearest hotel: No hotel found
# bilibino - nearest hotel: No hotel found
# thompson - nearest hotel: Thompson Inn
# la ronge - nearest hotel: La Ronge Hotel and Suites
# yellowknife - nearest hotel: No hotel found
# awjilah - nearest hotel: استراحة اوجلا
# kitob - nearest hotel: Гостевой дом
# alta - nearest hotel: Scandic Alta
# kirensk - nearest hotel: Ивушка
# la foa - nearest hotel: La table du banian
# petrolina - nearest hotel: Neuman
# alofi - nearest hotel: Stone Villas
# whitehorse - nearest hotel: The Beez Kneez Bakpakers Hostel
# smithers - nearest hotel: Sunshine Inn Hotel
# soe - nearest hotel: DENA
# cole harbour - nearest hotel: No hotel found
# zabol - nearest hotel: No hotel found
# ajdabiya - nearest hotel: فندق المدينة
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 650,
    frame_height = 450,
    hover_cols=["Hotel Name","Country"],
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
